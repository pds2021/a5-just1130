# %% [markdown]
# *Practical Data Science 20/21*
# # Programming Assignment 5 - Create your own App

# %% [markdown]
# In this programming assignment you'll build a model that serves as a foundation for your own app. To this end, you will create your own dataset, build a deep learning model on this data, and deploy it!

# %%
# !pip install -Uqq fastai  # upgrade fastai on colab
from fastai.vision.all import *
from fastai.vision.widgets import *

# %% [markdown]
# __Google Drive integration__
#
# If you want to store and access your downloaded data for this assignment you can use the following code:

# %%
from google.colab import drive
drive.mount('/content/drive')
# !mkdir /content/drive/My\ Drive/pds_a5
# %cd /content/drive/My\ Drive/pds_a5
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# mkdir: cannot create directory ‘/content/drive/My Drive/pds_a5’: File exists
# /content/drive/My Drive/pds_a5

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Develop an Application Idea

# %% [markdown]
# ___Free your mind - this part is totally up to you.___
#
# Think of an app that you'd like to build.
# *   What useful app have you been missing?
# *   Do you have any hobbies an app could be helpful for?
# *   Is this a suitable classification or regression task?
# *   How could you get the data?

# %%
# Write down your app idea here

# %% [markdown]
# You can get an inspiration from these Apps:
#
# <table>
# <tr>
# <td> <img src="https://github.com/hiromis/notes/raw/master/lesson3/5.png"> <br><a href="https://forums.fast.ai/t/share-your-work-here/27676/400">Guitar Classifier</a> by Christian Werner</td><td> <img src="https://github.com/hiromis/notes/raw/master/lesson3/6.png"><br><a href="https://forums.fast.ai/t/share-your-work-here/27676/340">Healthy or Not!</a> by Nikhil Utane </td><td> <img src="https://github.com/hiromis/notes/raw/master/lesson3/7.png"> <br><a href="https://forums.fast.ai/t/share-your-work-here/27676/333">Hummingbird Classifier</a> by Nissan Dookeran</td>
# </tr><tr>
# <td> <img src="https://github.com/hiromis/notes/raw/master/lesson3/8.png"> <br><a href="https://forums.fast.ai/t/share-your-work-here/27676/409">Edible Mushroom?</a> by Ramon</td><td> <img src="https://github.com/hiromis/notes/raw/master/lesson3/9.png"><br> <a href="https://forums.fast.ai/t/share-your-work-here/27676/387">Cousin Recognizer</a> by Charlie Harrington</td><td> <img src="https://github.com/hiromis/notes/raw/master/lesson3/10.png"><br> <a href="https://forums.fast.ai/t/share-your-work-here/27676/386">Emotion Classifier</a> by Ethan Sutin and Team 26</td>
# </tr><tr>
# <td> <img src="https://github.com/hiromis/notes/raw/master/lesson3/11.png"> <br><a href="https://forums.fast.ai/t/share-your-work-here/27676/350">American Sign Language</a> by Keyur Paralkar</td><td> <img src="https://github.com/hiromis/notes/raw/master/lesson3/12.png"> <br><a href="https://forums.fast.ai/t/share-your-work-here/27676/355">Your City from Space</a> by Henri Palacci</td><td> <img src="https://github.com/hiromis/notes/raw/master/lesson3/13.png"> <br><a href="https://forums.fast.ai/t/share-your-work-here/27676/367">Univariate TS as images using Gramian Angular Field</a> by Ignacio Oguiza</td>
# </tr><tr>
# <td> <img src="https://github.com/hiromis/notes/raw/master/lesson3/14.png"> <br><a href="https://forums.fast.ai/t/share-your-work-here/27676/348">Face Expression Recognition</a> by Pierre Guillou</td><td> <img src="https://github.com/hiromis/notes/raw/master/lesson3/15.png"><br><a href="https://forums.fast.ai/t/share-your-work-here/27676/352">Tumor-normal sequencing</a> by Alena Harley</td><td>  </td>
# </tr><table>

# %% [markdown]
# ## Creating your own Dataset
#
# Now you need to construct a dataset that allows you to train a model for your app. You learned about how to create a dataset in Lecture 7.
#
# Here, you can follow the steps from the lecture or look into the following ressources:
#
# *   A [tool](https://github.com/toffebjorkskog/ml-tools/blob/master/gi2ds.md) for excluding irrelevant images from Google Image Search results beforehand by @melonkernel
# *   See this [post](https://www.christianwerner.net/tech/Build-your-image-dataset-faster/) about an alternative image downloader/cleaner by @cwerner
# *   Of course, you can use your own data/images :)

# %% [markdown]
# ### 1. Dowload the data
# - You may use the helper functions from the lecture to get the image URLs
# - Create a new folder at your defined `path`
# - Use `download_image` to download the images into the corresponding (sub-)directories

# %%
# Write your code here

# %% [markdown]
# ### 2. Verify Images
# - First, create a list of all your images
# - Use `verify_images` and `unlink` to remove broken images

# %%
# Write your code here

# %% [markdown]
# ### 3. Create the DataBlock
# For this, you need to think of:
# - What kinds of data we are working with
# - How to get the list of items
# - How to label these items
# - How to create the validation set
#
# Use `RandomResizedCrop` for `item_tfms`with an image size of 224 px, and the appropriate `aug_transforms` as `batch_tfms`.

# %%
for image in os.listdir('/content/drive/MyDrive/pds_a5/imageBW'):
  img = PILImage.create(f'/content/drive/MyDrive/pds_a5/imageBW/{image}')
  img = img.resize((512,512))
  img.save(f'/content/drive/MyDrive/pds_a5/imageBW/{image}')

# %%
df = pd.DataFrame(columns=['X','Y'])
for image in os.listdir('/content/drive/MyDrive/pds_a5/imageBW'):
  df = df.append({'X':f'/content/drive/MyDrive/pds_a5/imageBW/{image}','Y':f'/content/drive/MyDrive/pds_a5/imageColor/{image}'},ignore_index=True)
df.head()
db = DataBlock(blocks=(ImageBlock,ImageBlock),
               get_x= ColReader('X'),
               get_y= ColReader('Y'))
dl = db.dataloaders(df,batch_size=4)
dl.show_batch()
dl.c= 3

# %%
learner = unet_learner(dl,models.resnet34,loss_func=MSELossFlat())

# %%
learner.lr_find()
# Out:
# SuggestedLRs(lr_min=0.0009120108559727668, lr_steep=3.630780702224001e-05)

# %%
learner.fit_one_cycle(10,pct_start=0.8,lr_max=3.630780702224001e-05)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.373262</td>
#       <td>1.676346</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.261031</td>
#       <td>1.466067</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.153088</td>
#       <td>1.150729</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.028396</td>
#       <td>0.745304</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.910014</td>
#       <td>0.498471</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.817555</td>
#       <td>0.417844</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.736069</td>
#       <td>0.400922</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.676438</td>
#       <td>0.378766</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.628463</td>
#       <td>0.348104</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.584886</td>
#       <td>0.349935</td>
#       <td>00:08</td>
#     </tr>
#   </tbody>
# </table>

# %%
im = PILImage.create('/content/drive/MyDrive/pds_a5/tets.jpg')
a = learner.predict(im)
#plt.imshow(a[0].permute(1,2,0))
PILImage.create(fn=a[0]).save('/content/drive/MyDrive/pds_a5/tetsPred.jpg')

# %%
learner.show_results(figsize=(20,20))

# %%
counter=0
for image in os.listdir('/content/drive/MyDrive/pds_a5/imageBW'):
  image = PILImage.create(f'/content/drive/MyDrive/pds_a5/imageBW/{image}')
  prediction = learner.predict(image)
  counter+=1
  PILImage.create(fn=prediction[0]).save(f'/content/drive/MyDrive/pds_a5/ImagePrediction/img{counter}.jpg')

# %%
dataFrame = pd.DataFrame(columns=['X','Y'])
for image in os.listdir('/content/drive/MyDrive/pds_a5/imageColor'):
  dataFrame = dataFrame.append({'X':f'/content/drive/MyDrive/pds_a5/imageColor/{image}','Y':'/content/drive/MyDrive/pds_a5/imageColor'},ignore_index=True)
for image in os.listdir('/content/drive/MyDrive/pds_a5/ImagePrediction'):
  dataFrame = dataFrame.append({'X':f'/content/drive/MyDrive/pds_a5/ImagePrediction/{image}','Y':'/content/drive/MyDrive/pds_a5/ImagePrediction'},ignore_index=True)
dataFrame.sample(30)
# Out:
#                                                             X                                              Y
# 77    /content/drive/MyDrive/pds_a5/ImagePrediction/img27.jpg  /content/drive/MyDrive/pds_a5/ImagePrediction
# 97    /content/drive/MyDrive/pds_a5/ImagePrediction/img47.jpg  /content/drive/MyDrive/pds_a5/ImagePrediction
# 68    /content/drive/MyDrive/pds_a5/ImagePrediction/img18.jpg  /content/drive/MyDrive/pds_a5/ImagePrediction
# 2    /content/drive/MyDrive/pds_a5/imageColor/landscape11.jpg       /content/drive/MyDrive/pds_a5/imageColor
# 24   /content/drive/MyDrive/pds_a5/imageColor/landscape25.jpg       /content/drive/MyDrive/pds_a5/imageColor
# 60    /content/drive/MyDrive/pds_a5/ImagePrediction/img10.jpg  /content/drive/MyDrive/pds_a5/ImagePrediction
# 74    /content/drive/MyDrive/pds_a5/ImagePrediction/img24.jpg  /content/drive/MyDrive/pds_a5/ImagePrediction
# 56     /content/drive/MyDrive/pds_a5/ImagePrediction/img6.jpg  /content/drive/MyDrive/pds_a5/ImagePrediction
# 0     /content/drive/MyDrive/pds_a5/imageColor/landscape1.jpg       /content/drive/MyDrive/pds_a5/imageColor
# 61    /content/drive/MyDrive/pds_a5/ImagePrediction/img11.jpg  /content/drive/MyDrive/pds_a5/ImagePrediction
# 18   /content/drive/MyDrive/pds_a5/imageColor/landscape17.jpg       /content/drive/MyDrive/pds_a5/imageColor
# 75    /content/drive/MyDrive/pds_a5/ImagePrediction/img25.jpg  /content/drive/MyDrive/pds_a5/ImagePrediction
# 30   /content/drive/MyDrive/pds_a5/imageColor/landscape31.jpg       /content/drive/MyDrive/pds_a5/imageColor
# 25   /content/drive/MyDrive/pds_a5/imageColor/landscape28.jpg       /content/drive/MyDrive/pds_a5/imageColor
# 52     /content/drive/MyDrive/pds_a5/ImagePrediction/img2.jpg  /content/drive/MyDrive/pds_a5/ImagePrediction
# 95    /content/drive/MyDrive/pds_a5/ImagePrediction/img45.jpg  /content/drive/MyDrive/pds_a5/ImagePrediction
# 50   /content/drive/MyDrive/pds_a5/imageColor/landscape52.jpg       /content/drive/MyDrive/pds_a5/imageColor
# 93    /content/drive/MyDrive/pds_a5/ImagePrediction/img43.jpg  /content/drive/MyDrive/pds_a5/ImagePrediction
# 45   /content/drive/MyDrive/pds_a5/imageColor/landscape47.jpg       /content/drive/MyDrive/pds_a5/imageColor
# 85    /content/drive/MyDrive/pds_a5/ImagePrediction/img35.jpg  /content/drive/MyDrive/pds_a5/ImagePrediction
# 38   /content/drive/MyDrive/pds_a5/imageColor/landscape40.jpg       /content/drive/MyDrive/pds_a5/imageColor
# 100   /content/drive/MyDrive/pds_a5/ImagePrediction/img50.jpg  /content/drive/MyDrive/pds_a5/ImagePrediction
# 96    /content/drive/MyDrive/pds_a5/ImagePrediction/img46.jpg  /content/drive/MyDrive/pds_a5/ImagePrediction
# 62    /content/drive/MyDrive/pds_a5/ImagePrediction/img12.jpg  /content/drive/MyDrive/pds_a5/ImagePrediction
# 64    /content/drive/MyDrive/pds_a5/ImagePrediction/img14.jpg  /content/drive/MyDrive/pds_a5/ImagePrediction
# 101   /content/drive/MyDrive/pds_a5/ImagePrediction/img51.jpg  /content/drive/MyDrive/pds_a5/ImagePrediction
# 15   /content/drive/MyDrive/pds_a5/imageColor/landscape20.jpg       /content/drive/MyDrive/pds_a5/imageColor
# 94    /content/drive/MyDrive/pds_a5/ImagePrediction/img44.jpg  /content/drive/MyDrive/pds_a5/ImagePrediction
# 47   /content/drive/MyDrive/pds_a5/imageColor/landscape49.jpg       /content/drive/MyDrive/pds_a5/imageColor
# 80    /content/drive/MyDrive/pds_a5/ImagePrediction/img30.jpg  /content/drive/MyDrive/pds_a5/ImagePrediction

# %%
dbCrit = DataBlock(blocks=(ImageBlock,CategoryBlock),
                  get_x= ColReader('X'),
                  get_y= ColReader('Y'))
dataloaderCrit = dbCrit.dataloaders(dataFrame,bs=1)
dataloaderCrit.show_batch()
dataloaderCrit.c = 3

# %%
# !nvidia-smi
# Out:
# Sat Jan 16 13:05:37 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.27.04    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   75C    P0    33W /  70W |  14337MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from fastai.vision.gan import *
crit_learner = Learner(dataloaderCrit,gan_critic(),metrics=accuracy_thresh_expand, loss_func=AdaptiveLoss(nn.BCEWithLogitsLoss()))

# %%
crit_learner.lr_find()
# Out:
# SuggestedLRs(lr_min=0.00043651582673192023, lr_steep=1.3182567358016968)

# %%
crit_learner.fit_one_cycle(10,0.00043651582673192023)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh_expand</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.715363</td>
#       <td>0.705518</td>
#       <td>0.450000</td>
#       <td>00:55</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.704120</td>
#       <td>0.694360</td>
#       <td>0.450000</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.703671</td>
#       <td>0.688161</td>
#       <td>0.550000</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.679331</td>
#       <td>0.620519</td>
#       <td>0.629370</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.820736</td>
#       <td>0.658548</td>
#       <td>0.682105</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.564257</td>
#       <td>0.366939</td>
#       <td>0.863020</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.419067</td>
#       <td>0.512610</td>
#       <td>0.811831</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.377641</td>
#       <td>0.299211</td>
#       <td>0.867598</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.283878</td>
#       <td>0.340849</td>
#       <td>0.851605</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.335668</td>
#       <td>0.332797</td>
#       <td>0.853151</td>
#       <td>00:54</td>
#     </tr>
#   </tbody>
# </table>

# %%
crit_learner.save('/content/drive/MyDrive/pds_a5/models/critic')
# Out:
# Path('/content/drive/MyDrive/pds_a5/models/critic.pth')

# %%
# Write your code here

# %% [markdown]
# ### 4. Create the DataLoaders

# %%
# Write your code here

# %% [markdown]
# ### 5. Take a look at some of your pictures.
# Does everything look as expected?

# %%
# Write your code here

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### 6. Create a learner
#
# Create an appropriate learner for your data
# - Choose an appropriate model [architecture](https://fastai1.fast.ai/vision.models.html)
# - Choose appropriate [metrics](https://docs.fast.ai/metrics.html) for your task

# %%
# Write your code here

# %% [markdown]
# ### 7. Fit the model
#
# Use your knowdledge on model training to fit your model!

# %%
# Write your code here

# %% [markdown]
# ### 8. Evaluate the model
#
# You' ve already seen many ways to evaluate a model. Evaluate your model in a qualitative and quantitative manner.

# %%
# Write your code here

# %% [markdown]
# ### 9. Clean your data
#
# Based on the evaluation, you may want to clean your data using the `ImageClassifierCleaner`.
# - Remeber to delete the selected data after using the cleaner:
#     ```python
#     for idx in cleaner.delete(): cleaner.fns[idx].unlink()
#     ```
#
#
# - Once we've cleaned up our data, we can retrain our model.

# %%
# Write your code here

# %% [markdown]
# ## Turning Your Model into an Online Application

# %% [markdown]
# Now, take your app into production. You can follow the steps from the lecure:
#
# - Export your model via `learn.export`
# - Upload your model to [Github Releases](https://docs.github.com/en/free-pro-team@latest/github/administering-a-repository/about-releases) to make it publicly available at your repository.
# - Create and upload a new notebook that only contains the necassary code and IPython widgets for your App.
#     - Remeber to download the exported model from *Github Releases*
#     - Include a brief description of your app and the functionalities
# - Publish your web app on [Binder](https://mybinder.org/) using Voilà
#
# You can use the [example](https://github.com/pds2021/course/blob/main/nbs/07_Bear_App.ipynb) from the lecture as an orientation.
#
# If you're familiar with the world of web application development, you're free to use these skills and all your tools and ressources!

# %%
# Write your code here

# %% [markdown]
# ## Finally, Provide a Link to Your App

# %%
# Provide the link to your web app
